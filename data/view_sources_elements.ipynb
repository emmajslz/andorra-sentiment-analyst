# %%
import pandas as pd

# %%
sources_elements = pd.read_csv('sources_elements.csv', delimiter=';').set_index('source')

# %%
sources_elements
# Out:
#          dynamic static               structure comments next_page  \
# source
# altaveu      yes    yes          numbered pages      yes   &_page=
# forum         no    yes          numbered pages       no    /page/
# bondia       yes     no  dynamic numbered pages       no    &page=
# periodic     yes     no             single page       no         -
# ara          yes     no          load more page       no         -
# diari        yes     no               next page       no         -
# ser          yes     no               next page       no         -
#
#                                              cookies  \
# source
# altaveu               //*[contains(text(), "AGREE")]
# forum                                              -
# bondia                                             -
# periodic                                           -
# ara       //button[@id="didomi-notice-agree-button"]
# diari      //button[@class="cky-btn cky-btn-accept"]
# ...

# %%
sources_elements['next_page']
# Out:
# source
# altaveu     &_page=
# forum        /page/
# bondia       &page=
# periodic          -
# ara               -
# diari             -
# ser               -
# Name: next_page, dtype: object
